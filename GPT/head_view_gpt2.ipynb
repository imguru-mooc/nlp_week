# %%
# !pip install bertviz
# Out:
# Collecting bertviz
#   Downloading bertviz-1.2.0-py3-none-any.whl (156 kB)
# Requirement already satisfied: sentencepiece in c:\programdata\anaconda3\lib\site-packages (from bertviz) (0.1.96)
# Requirement already satisfied: regex in c:\programdata\anaconda3\lib\site-packages (from bertviz) (2021.4.4)
# Collecting boto3
#   Downloading boto3-1.18.35-py3-none-any.whl (131 kB)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from bertviz) (2.24.0)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from bertviz) (4.59.0)
# Collecting torch>=1.0
#   Downloading torch-1.9.0-cp38-cp38-win_amd64.whl (222.0 MB)
# Requirement already satisfied: transformers>=2.0 in c:\programdata\anaconda3\lib\site-packages (from bertviz) (4.9.2)
# Requirement already satisfied: typing-extensions in c:\programdata\anaconda3\lib\site-packages (from torch>=1.0->bertviz) (3.7.4.3)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in c:\programdata\anaconda3\lib\site-packages (from transformers>=2.0->bertviz) (0.10.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\jikim\appdata\roaming\python\python38\site-packages (from transformers>=2.0->bertviz) (1.19.5)
# Requirement already satisfied: sacremoses in c:\programdata\anaconda3\lib\site-packages (from transformers>=2.0->bertviz) (0.0.45)
# Requirement already satisfied: pyyaml>=5.1 in c:\programdata\anaconda3\lib\site-packages (from transformers>=2.0->bertviz) (5.4.1)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from transformers>=2.0->bertviz) (20.9)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from transformers>=2.0->bertviz) (3.0.12)
# Requirement already satisfied: huggingface-hub==0.0.12 in c:\programdata\anaconda3\lib\site-packages (from transformers>=2.0->bertviz) (0.0.12)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging->transformers>=2.0->bertviz) (2.4.7)
# Collecting botocore<1.22.0,>=1.21.35
#   Downloading botocore-1.21.35-py3-none-any.whl (7.9 MB)
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.0-py3-none-any.whl (79 kB)
# Collecting jmespath<1.0.0,>=0.7.1
#   Using cached jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\programdata\anaconda3\lib\site-packages (from botocore<1.22.0,>=1.21.35->boto3->bertviz) (1.25.11)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\programdata\anaconda3\lib\site-packages (from botocore<1.22.0,>=1.21.35->boto3->bertviz) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.22.0,>=1.21.35->boto3->bertviz) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->bertviz) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->bertviz) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->bertviz) (3.0.4)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from sacremoses->transformers>=2.0->bertviz) (1.0.1)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from sacremoses->transformers>=2.0->bertviz) (7.1.2)
# Installing collected packages: jmespath, botocore, s3transfer, torch, boto3, bertviz
# Successfully installed bertviz-1.2.0 boto3-1.18.35 botocore-1.21.35 jmespath-0.10.0 s3transfer-0.5.0 torch-1.9.0

# %%
from bertviz import head_view
from transformers import GPT2Tokenizer, GPT2Model

# %%
model_version = 'gpt2'
model = GPT2Model.from_pretrained(model_version, output_attentions=True)
tokenizer = GPT2Tokenizer.from_pretrained(model_version)
text = "The quick brown fox jumps over the lazy dogs."
inputs = tokenizer.encode_plus(text, return_tensors='pt', add_special_tokens=True)
input_ids = inputs['input_ids']
attention = model(input_ids)[-1]
input_id_list = input_ids[0].tolist() # Batch index 0
tokens = tokenizer.convert_ids_to_tokens(input_id_list)
head_view(attention, tokens)
# Out:
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id='bertviz-dff568a9116142eea08f5a22a02faf9c'>
#             <span style="user-select:none">
#                 Layer: <select id="layer"></select>
#
#             </span>
#             <div id='vis'></div>
#         </div>
