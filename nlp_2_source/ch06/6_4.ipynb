# %% [markdown]
# ### LSTM을 사용한 언어 모델

# %%
import sys
sys.path.append('..')
from common.time_layers import *
from common.base_model import BaseModel


class Rnnlm(BaseModel):
    def __init__(self, vocab_size=10000, wordvec_size=100, hidden_size=100):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        # 가중치 초기화
        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(4 * H).astype('f')
        affine_W = (rn(H, V) / np.sqrt(H)).astype('f')
        affine_b = np.zeros(V).astype('f')

        # 계층 생성
        self.layers = [
            TimeEmbedding(embed_W),
            TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful=True),
            TimeAffine(affine_W, affine_b)
        ]
        self.loss_layer = TimeSoftmaxWithLoss()
        self.lstm_layer = self.layers[1]

        # 모든 가중치와 기울기를 리스트에 모은다.
        self.params, self.grads = [], []
        for layer in self.layers:
            self.params += layer.params
            self.grads += layer.grads

    def predict(self, xs):
        for layer in self.layers:
            xs = layer.forward(xs)
        return xs

    def forward(self, xs, ts):
        score = self.predict(xs)
        loss = self.loss_layer.forward(score, ts)
        return loss

    def backward(self, dout=1):
        dout = self.loss_layer.backward(dout)
        for layer in reversed(self.layers):
            dout = layer.backward(dout)
        return dout

    def reset_state(self):
        self.lstm_layer.reset_state()

# %% [markdown]
# ### 학습을 위한 코드

# %%
import sys
sys.path.append('..')
from common.optimizer import SGD
from common.trainer import RnnlmTrainer
from common.util import eval_perplexity
from dataset import ptb
from rnnlm import Rnnlm


# 하이퍼파라미터 설정
batch_size = 20
wordvec_size = 100
hidden_size = 100  # RNN의 은닉 상태 벡터의 원소 수
time_size = 35     # RNN을 펼치는 크기
lr = 20.0
max_epoch = 4
max_grad = 0.25

# 학습 데이터 읽기
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_test, _, _ = ptb.load_data('test')
vocab_size = len(word_to_id)
xs = corpus[:-1]
ts = corpus[1:]

# 모델 생성
model = Rnnlm(vocab_size, wordvec_size, hidden_size)
optimizer = SGD(lr)
trainer = RnnlmTrainer(model, optimizer)

# 기울기 클리핑을 적용하여 학습
trainer.fit(xs, ts, max_epoch, batch_size, time_size, max_grad,
            eval_interval=20)
trainer.plot(ylim=(0, 500))

# 테스트 데이터로 평가
model.reset_state()
ppl_test = eval_perplexity(model, corpus_test)
print('테스트 퍼플렉서티: ', ppl_test)

# 매개변수 저장
model.save_params()
# Out:
# | 에폭 1 |  반복 1 / 1327 | 시간 0[s] | 퍼플렉서티 10001.54
# | 에폭 1 |  반복 21 / 1327 | 시간 8[s] | 퍼플렉서티 2703.67
# | 에폭 1 |  반복 41 / 1327 | 시간 16[s] | 퍼플렉서티 1248.42
# | 에폭 1 |  반복 61 / 1327 | 시간 25[s] | 퍼플렉서티 972.45
# | 에폭 1 |  반복 81 / 1327 | 시간 34[s] | 퍼플렉서티 795.64
# | 에폭 1 |  반복 101 / 1327 | 시간 43[s] | 퍼플렉서티 662.02
# | 에폭 1 |  반복 121 / 1327 | 시간 52[s] | 퍼플렉서티 643.50
# | 에폭 1 |  반복 141 / 1327 | 시간 60[s] | 퍼플렉서티 596.35
# | 에폭 1 |  반복 161 / 1327 | 시간 69[s] | 퍼플렉서티 577.79
# | 에폭 1 |  반복 181 / 1327 | 시간 78[s] | 퍼플렉서티 568.22
# | 에폭 1 |  반복 201 / 1327 | 시간 87[s] | 퍼플렉서티 502.29
# | 에폭 1 |  반복 221 / 1327 | 시간 95[s] | 퍼플렉서티 484.25
# | 에폭 1 |  반복 241 / 1327 | 시간 104[s] | 퍼플렉서티 433.38
# | 에폭 1 |  반복 261 / 1327 | 시간 113[s] | 퍼플렉서티 461.93
# | 에폭 1 |  반복 281 / 1327 | 시간 122[s] | 퍼플렉서티 449.90
# | 에폭 1 |  반복 301 / 1327 | 시간 131[s] | 퍼플렉서티 392.86
# | 에폭 1 |  반복 321 / 1327 | 시간 139[s] | 퍼플렉서티 342.96
# | 에폭 1 |  반복 341 / 1327 | 시간 148[s] | 퍼플렉서티 398.60
# | 에폭 1 |  반복 361 / 1327 | 시간 157[s] | 퍼플렉서티 398.45
# | 에폭 1 |  반복 381 / 1327 | 시간 166[s] | 퍼플렉서티 328.50
# | 에폭 1 |  반복 401 / 1327 | 시간 174[s] | 퍼플렉서티 352.91
# | 에폭 1 |  반복 421 / 1327 | 시간 183[s] | 퍼플렉서티 342.63
# | 에폭 1 |  반복 441 / 1327 | 시간 192[s] | 퍼플렉서티 328.26
# | 에폭 1 |  반복 461 / 1327 | 시간 201[s] | 퍼플렉서티 324.35
# | 에폭 1 |  반복 481 / 1327 | 시간 209[s] | 퍼플렉서티 305.45
# | 에폭 1 |  반복 501 / 1327 | 시간 218[s] | 퍼플렉서티 313.13
# | 에폭 1 |  반복 521 / 1327 | 시간 228[s] | 퍼플렉서티 296.98
# | 에폭 1 |  반복 541 / 1327 | 시간 240[s] | 퍼플렉서티 320.42
# | 에폭 1 |  반복 561 / 1327 | 시간 250[s] | 퍼플렉서티 283.68
# | 에폭 1 |  반복 581 / 1327 | 시간 258[s] | 퍼플렉서티 257.77
# | 에폭 1 |  반복 601 / 1327 | 시간 267[s] | 퍼플렉서티 336.97
# | 에폭 1 |  반복 621 / 1327 | 시간 276[s] | 퍼플렉서티 312.41
# | 에폭 1 |  반복 641 / 1327 | 시간 285[s] | 퍼플렉서티 281.97
# | 에폭 1 |  반복 661 / 1327 | 시간 293[s] | 퍼플렉서티 262.57
# | 에폭 1 |  반복 681 / 1327 | 시간 302[s] | 퍼플렉서티 230.76
# | 에폭 1 |  반복 701 / 1327 | 시간 311[s] | 퍼플렉서티 249.60
# | 에폭 1 |  반복 721 / 1327 | 시간 320[s] | 퍼플렉서티 257.22
# | 에폭 1 |  반복 741 / 1327 | 시간 328[s] | 퍼플렉서티 222.41
# | 에폭 1 |  반복 761 / 1327 | 시간 337[s] | 퍼플렉서티 232.24
# | 에폭 1 |  반복 781 / 1327 | 시간 346[s] | 퍼플렉서티 219.47
# | 에폭 1 |  반복 801 / 1327 | 시간 355[s] | 퍼플렉서티 241.24
# | 에폭 1 |  반복 821 / 1327 | 시간 364[s] | 퍼플렉서티 225.67
# | 에폭 1 |  반복 841 / 1327 | 시간 373[s] | 퍼플렉서티 227.59
# | 에폭 1 |  반복 861 / 1327 | 시간 384[s] | 퍼플렉서티 223.11
# | 에폭 1 |  반복 881 / 1327 | 시간 394[s] | 퍼플렉서티 206.26
# | 에폭 1 |  반복 901 / 1327 | 시간 404[s] | 퍼플렉서티 256.54
# | 에폭 1 |  반복 921 / 1327 | 시간 414[s] | 퍼플렉서티 224.86
# | 에폭 1 |  반복 941 / 1327 | 시간 424[s] | 퍼플렉서티 230.37
# | 에폭 1 |  반복 961 / 1327 | 시간 433[s] | 퍼플렉서티 245.02
# | 에폭 1 |  반복 981 / 1327 | 시간 443[s] | 퍼플렉서티 230.56
# | 에폭 1 |  반복 1001 / 1327 | 시간 454[s] | 퍼플렉서티 193.65
# | 에폭 1 |  반복 1021 / 1327 | 시간 464[s] | 퍼플렉서티 226.94
# | 에폭 1 |  반복 1041 / 1327 | 시간 474[s] | 퍼플렉서티 207.17
# | 에폭 1 |  반복 1061 / 1327 | 시간 485[s] | 퍼플렉서티 199.32
# | 에폭 1 |  반복 1081 / 1327 | 시간 496[s] | 퍼플렉서티 170.56
# | 에폭 1 |  반복 1101 / 1327 | 시간 507[s] | 퍼플렉서티 194.14
# | 에폭 1 |  반복 1121 / 1327 | 시간 519[s] | 퍼플렉서티 227.22
# | 에폭 1 |  반복 1141 / 1327 | 시간 529[s] | 퍼플렉서티 207.52
# | 에폭 1 |  반복 1161 / 1327 | 시간 540[s] | 퍼플렉서티 199.34
# | 에폭 1 |  반복 1181 / 1327 | 시간 550[s] | 퍼플렉서티 190.72
# | 에폭 1 |  반복 1201 / 1327 | 시간 560[s] | 퍼플렉서티 162.93
# | 에폭 1 |  반복 1221 / 1327 | 시간 571[s] | 퍼플렉서티 160.93
# | 에폭 1 |  반복 1241 / 1327 | 시간 582[s] | 퍼플렉서티 190.14
# | 에폭 1 |  반복 1261 / 1327 | 시간 592[s] | 퍼플렉서티 172.78
# | 에폭 1 |  반복 1281 / 1327 | 시간 602[s] | 퍼플렉서티 179.03
# | 에폭 1 |  반복 1301 / 1327 | 시간 613[s] | 퍼플렉서티 222.44
# | 에폭 1 |  반복 1321 / 1327 | 시간 623[s] | 퍼플렉서티 210.82
# | 에폭 2 |  반복 1 / 1327 | 시간 627[s] | 퍼플렉서티 223.70
# | 에폭 2 |  반복 21 / 1327 | 시간 639[s] | 퍼플렉서티 205.77
# | 에폭 2 |  반복 41 / 1327 | 시간 651[s] | 퍼플렉서티 189.84
# | 에폭 2 |  반복 61 / 1327 | 시간 660[s] | 퍼플렉서티 177.09
# | 에폭 2 |  반복 81 / 1327 | 시간 670[s] | 퍼플렉서티 158.92
# | 에폭 2 |  반복 101 / 1327 | 시간 678[s] | 퍼플렉서티 154.05
# | 에폭 2 |  반복 121 / 1327 | 시간 687[s] | 퍼플렉서티 159.44
# | 에폭 2 |  반복 141 / 1327 | 시간 696[s] | 퍼플렉서티 178.91
# | 에폭 2 |  반복 161 / 1327 | 시간 705[s] | 퍼플렉서티 193.69
# | 에폭 2 |  반복 181 / 1327 | 시간 714[s] | 퍼플렉서티 199.77
# | 에폭 2 |  반복 201 / 1327 | 시간 723[s] | 퍼플렉서티 185.73
# | 에폭 2 |  반복 221 / 1327 | 시간 732[s] | 퍼플렉서티 184.10
# | 에폭 2 |  반복 241 / 1327 | 시간 741[s] | 퍼플렉서티 175.67
# | 에폭 2 |  반복 261 / 1327 | 시간 749[s] | 퍼플렉서티 186.01
# | 에폭 2 |  반복 281 / 1327 | 시간 758[s] | 퍼플렉서티 185.22
# | 에폭 2 |  반복 301 / 1327 | 시간 767[s] | 퍼플렉서티 167.16
# | 에폭 2 |  반복 321 / 1327 | 시간 775[s] | 퍼플렉서티 140.16
# | 에폭 2 |  반복 341 / 1327 | 시간 784[s] | 퍼플렉서티 170.81
# | 에폭 2 |  반복 361 / 1327 | 시간 793[s] | 퍼플렉서티 196.55
# | 에폭 2 |  반복 381 / 1327 | 시간 802[s] | 퍼플렉서티 153.01
# | 에폭 2 |  반복 401 / 1327 | 시간 810[s] | 퍼플렉서티 168.81
# | 에폭 2 |  반복 421 / 1327 | 시간 819[s] | 퍼플렉서티 156.52
# | 에폭 2 |  반복 441 / 1327 | 시간 828[s] | 퍼플렉서티 163.03
# | 에폭 2 |  반복 461 / 1327 | 시간 837[s] | 퍼플렉서티 157.29
# | 에폭 2 |  반복 481 / 1327 | 시간 845[s] | 퍼플렉서티 156.01
# | 에폭 2 |  반복 501 / 1327 | 시간 854[s] | 퍼플렉서티 169.66
# | 에폭 2 |  반복 521 / 1327 | 시간 863[s] | 퍼플렉서티 172.14
# | 에폭 2 |  반복 541 / 1327 | 시간 872[s] | 퍼플렉서티 176.05
# | 에폭 2 |  반복 561 / 1327 | 시간 881[s] | 퍼플렉서티 155.54
# | 에폭 2 |  반복 581 / 1327 | 시간 890[s] | 퍼플렉서티 138.18
# | 에폭 2 |  반복 601 / 1327 | 시간 898[s] | 퍼플렉서티 189.94
# | 에폭 2 |  반복 621 / 1327 | 시간 907[s] | 퍼플렉서티 182.15
# | 에폭 2 |  반복 641 / 1327 | 시간 916[s] | 퍼플렉서티 163.77
# | 에폭 2 |  반복 661 / 1327 | 시간 925[s] | 퍼플렉서티 154.71
# | 에폭 2 |  반복 681 / 1327 | 시간 934[s] | 퍼플렉서티 129.49
# | 에폭 2 |  반복 701 / 1327 | 시간 943[s] | 퍼플렉서티 151.66
# | 에폭 2 |  반복 721 / 1327 | 시간 952[s] | 퍼플렉서티 162.31
# | 에폭 2 |  반복 741 / 1327 | 시간 961[s] | 퍼플렉서티 134.41
# | 에폭 2 |  반복 761 / 1327 | 시간 970[s] | 퍼플렉서티 132.76
# | 에폭 2 |  반복 781 / 1327 | 시간 979[s] | 퍼플렉서티 136.24
# | 에폭 2 |  반복 801 / 1327 | 시간 988[s] | 퍼플렉서티 149.90
# | 에폭 2 |  반복 821 / 1327 | 시간 996[s] | 퍼플렉서티 144.93
# | 에폭 2 |  반복 841 / 1327 | 시간 1005[s] | 퍼플렉서티 145.03
# | 에폭 2 |  반복 861 / 1327 | 시간 1014[s] | 퍼플렉서티 147.50
# | 에폭 2 |  반복 881 / 1327 | 시간 1024[s] | 퍼플렉서티 130.41
# | 에폭 2 |  반복 901 / 1327 | 시간 1033[s] | 퍼플렉서티 165.54
# | 에폭 2 |  반복 921 / 1327 | 시간 1042[s] | 퍼플렉서티 147.06
# | 에폭 2 |  반복 941 / 1327 | 시간 1051[s] | 퍼플렉서티 154.55
# | 에폭 2 |  반복 961 / 1327 | 시간 1060[s] | 퍼플렉서티 163.99
# | 에폭 2 |  반복 981 / 1327 | 시간 1069[s] | 퍼플렉서티 155.91
# | 에폭 2 |  반복 1001 / 1327 | 시간 1078[s] | 퍼플렉서티 132.55
# | 에폭 2 |  반복 1021 / 1327 | 시간 1087[s] | 퍼플렉서티 157.47
# | 에폭 2 |  반복 1041 / 1327 | 시간 1096[s] | 퍼플렉서티 143.49
# | 에폭 2 |  반복 1061 / 1327 | 시간 1105[s] | 퍼플렉서티 128.83
# | 에폭 2 |  반복 1081 / 1327 | 시간 1113[s] | 퍼플렉서티 112.14
# | 에폭 2 |  반복 1101 / 1327 | 시간 1122[s] | 퍼플렉서티 121.74
# | 에폭 2 |  반복 1121 / 1327 | 시간 1131[s] | 퍼플렉서티 155.92
# | 에폭 2 |  반복 1141 / 1327 | 시간 1140[s] | 퍼플렉서티 143.13
# | 에폭 2 |  반복 1161 / 1327 | 시간 1149[s] | 퍼플렉서티 134.00
# | 에폭 2 |  반복 1181 / 1327 | 시간 1158[s] | 퍼플렉서티 135.30
# | 에폭 2 |  반복 1201 / 1327 | 시간 1167[s] | 퍼플렉서티 113.11
# | 에폭 2 |  반복 1221 / 1327 | 시간 1175[s] | 퍼플렉서티 109.27
# | 에폭 2 |  반복 1241 / 1327 | 시간 1184[s] | 퍼플렉서티 131.86
# | 에폭 2 |  반복 1261 / 1327 | 시간 1193[s] | 퍼플렉서티 124.72
